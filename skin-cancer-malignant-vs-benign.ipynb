# %% [markdown]
# # Import Necessary Library

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 

from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential 
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras import regularizers
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the Data

# %% [markdown]
# **Read Train Data and store it in dataframe**

# %%
# Generate data paths with labels
train_data_dir = '/kaggle/input/skin-cancer-malignant-vs-benign/train'
filepaths = []
labels = []

folds = os.listdir(train_data_dir)
for fold in folds:
    foldpath = os.path.join(train_data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
train_df = pd.concat([Fseries, Lseries], axis= 1)

# %%
train_df
# Out:
#                                               filepaths     labels
# 0     /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 1     /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 2     /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 3     /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 4     /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# ...                                                 ...        ...
# 2632  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 2633  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 2634  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 2635  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 2636  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
#
# [2637 rows x 2 columns]

# %% [markdown]
# **Read Test Data and store it in dataframe**

# %%
# Generate data paths with labels
test_data_dir = '/kaggle/input/skin-cancer-malignant-vs-benign/test'
filepaths = []
labels = []

folds = os.listdir(test_data_dir)
for fold in folds:
    foldpath = os.path.join(test_data_dir, fold)
    filelist = os.listdir(foldpath)
    for file in filelist:
        fpath = os.path.join(foldpath, file)
        
        filepaths.append(fpath)
        labels.append(fold)

# Concatenate data paths with labels into one dataframe
Fseries = pd.Series(filepaths, name= 'filepaths')
Lseries = pd.Series(labels, name='labels')
test_df = pd.concat([Fseries, Lseries], axis= 1)

# %%
test_df
# Out:
#                                              filepaths     labels
# 0    /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 1    /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 2    /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 3    /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# 4    /kaggle/input/skin-cancer-malignant-vs-benign/...     benign
# ..                                                 ...        ...
# 655  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 656  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 657  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 658  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
# 659  /kaggle/input/skin-cancer-malignant-vs-benign/...  malignant
#
# [660 rows x 2 columns]

# %% [markdown]
# **Create image data generator to make the pics have same size and every turn take same batch size**

# %%
batch_size = 16
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)

tr_gen = ImageDataGenerator()
ts_gen = ImageDataGenerator()

train_gen = tr_gen.flow_from_dataframe( train_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= True, batch_size= batch_size)

test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepaths', y_col= 'labels', target_size= img_size, class_mode= 'categorical',
                                    color_mode= 'rgb', shuffle= False, batch_size= batch_size)
# Out:
# Found 2637 validated image filenames belonging to 2 classes.
# Found 660 validated image filenames belonging to 2 classes.

# %% [markdown]
# **Show sample from train data**

# %%
g_dict = train_gen.class_indices      
classes = list(g_dict.keys())      
images, labels = next(train_gen)    

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255  
    plt.imshow(image)
    index = np.argmax(labels[i]) 
    class_name = classes[index]   
    plt.title(class_name, color= 'blue', fontsize= 12)
    plt.axis('off')
plt.show()

# %% [markdown]
# # Build The Model

# %%
model = Sequential([
    Conv2D(512, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    
    Conv2D(filters=256, kernel_size=(3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    
    Conv2D(filters=128, kernel_size=(3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),
    
    Conv2D(filters=64, kernel_size=(3,3), activation="relu"),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.2),

    # Fully Connected layers
    Flatten(),
    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),
    # Output layer
    Dense(2, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 512)  │        14,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 222, 222, 512)  │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 512)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 111, 111, 512)  │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 256)  │     1,179,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 109, 109, 256)  │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 54, 54, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 52, 52, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 24, 24, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 24, 24, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 12, 12, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │       294,944 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 32)             │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,862,050 (7.10 MB)
#  Trainable params: 1,860,066 (7.10 MB)
#  Non-trainable params: 1,984 (7.75 KB)

# %%
model.compile(optimizer=Adam(learning_rate= 0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history1 = model.fit(train_gen,
                    validation_data = test_gen,
                     batch_size = 64,
                    epochs = 50)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725136438.042230      69 service.cc:145] XLA service 0x7e0bd0005910 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1725136438.042295      69 service.cc:153]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
#   1/165 ━━━━━━━━━━━━━━━━━━━━ 1:16:59 28s/step - accuracy: 0.3750 - loss: 1.5698
# I0000 00:00:1725136461.681401      69 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 78s 304ms/step - accuracy: 0.7040 - loss: 0.6534 - val_accuracy: 0.6652 - val_loss: 0.6686
# Epoch 2/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.7712 - loss: 0.4707 - val_accuracy: 0.5985 - val_loss: 2.0490
# Epoch 3/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.7755 - loss: 0.4467 - val_accuracy: 0.7985 - val_loss: 0.3874
# Epoch 4/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8022 - loss: 0.4154 - val_accuracy: 0.7909 - val_loss: 0.3947
# Epoch 5/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8083 - loss: 0.3989 - val_accuracy: 0.7455 - val_loss: 0.5086
# Epoch 6/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8228 - loss: 0.3625 - val_accuracy: 0.7909 - val_loss: 0.3901
# Epoch 7/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8067 - loss: 0.3949 - val_accuracy: 0.7924 - val_loss: 0.3940
# Epoch 8/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8289 - loss: 0.3515 - val_accuracy: 0.7955 - val_loss: 0.4070
# Epoch 9/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8492 - loss: 0.3356 - val_accuracy: 0.8152 - val_loss: 0.3802
# Epoch 10/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8444 - loss: 0.3414 - val_accuracy: 0.8106 - val_loss: 0.3731
# Epoch 11/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8267 - loss: 0.3524 - val_accuracy: 0.7076 - val_loss: 0.5510
# Epoch 12/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8468 - loss: 0.3096 - val_accuracy: 0.8561 - val_loss: 0.3432
# Epoch 13/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8518 - loss: 0.3046 - val_accuracy: 0.7758 - val_loss: 0.4747
# Epoch 14/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8736 - loss: 0.2905 - val_accuracy: 0.8424 - val_loss: 0.3450
# Epoch 15/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - accuracy: 0.8835 - loss: 0.2761 - val_accuracy: 0.8106 - val_loss: 0.4034
# Epoch 16/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8814 - loss: 0.2869 - val_accuracy: 0.8091 - val_loss: 0.3991
# Epoch 17/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8844 - loss: 0.2755 - val_accuracy: 0.8485 - val_loss: 0.3189
# Epoch 18/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8820 - loss: 0.2749 - val_accuracy: 0.7061 - val_loss: 0.6469
# Epoch 19/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8695 - loss: 0.2945 - val_accuracy: 0.7742 - val_loss: 0.4699
# Epoch 20/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8663 - loss: 0.2817 - val_accuracy: 0.8485 - val_loss: 0.3121
# Epoch 21/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8818 - loss: 0.2760 - val_accuracy: 0.8015 - val_loss: 0.3892
# Epoch 22/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.8778 - loss: 0.2517 - val_accuracy: 0.8212 - val_loss: 0.3719
# Epoch 23/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8865 - loss: 0.2422 - val_accuracy: 0.8106 - val_loss: 0.4165
# Epoch 24/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.8979 - loss: 0.2573 - val_accuracy: 0.8515 - val_loss: 0.3279
# Epoch 25/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9091 - loss: 0.2293 - val_accuracy: 0.8076 - val_loss: 0.4229
# Epoch 26/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9123 - loss: 0.2047 - val_accuracy: 0.8348 - val_loss: 0.3831
# Epoch 27/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9130 - loss: 0.2049 - val_accuracy: 0.8303 - val_loss: 0.3871
# Epoch 28/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9279 - loss: 0.1879 - val_accuracy: 0.7788 - val_loss: 0.5253
# Epoch 29/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9244 - loss: 0.1757 - val_accuracy: 0.8424 - val_loss: 0.3659
# Epoch 30/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9322 - loss: 0.1731 - val_accuracy: 0.8288 - val_loss: 0.4328
# Epoch 31/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9308 - loss: 0.1817 - val_accuracy: 0.8303 - val_loss: 0.3971
# Epoch 32/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9178 - loss: 0.1936 - val_accuracy: 0.7788 - val_loss: 0.6940
# Epoch 33/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - accuracy: 0.9319 - loss: 0.1689 - val_accuracy: 0.8348 - val_loss: 0.4017
# Epoch 34/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9373 - loss: 0.1611 - val_accuracy: 0.7970 - val_loss: 0.6134
# Epoch 35/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9531 - loss: 0.1382 - val_accuracy: 0.8394 - val_loss: 0.4580
# Epoch 36/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9338 - loss: 0.1689 - val_accuracy: 0.8303 - val_loss: 0.4542
# Epoch 37/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9439 - loss: 0.1416 - val_accuracy: 0.8136 - val_loss: 0.4922
# Epoch 38/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9501 - loss: 0.1262 - val_accuracy: 0.8030 - val_loss: 0.5654
# Epoch 39/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9590 - loss: 0.1213 - val_accuracy: 0.8227 - val_loss: 0.5437
# Epoch 40/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9530 - loss: 0.1224 - val_accuracy: 0.8182 - val_loss: 0.4833
# Epoch 41/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9491 - loss: 0.1201 - val_accuracy: 0.8227 - val_loss: 0.5192
# Epoch 42/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9485 - loss: 0.1377 - val_accuracy: 0.8197 - val_loss: 0.5096
# Epoch 43/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9550 - loss: 0.1295 - val_accuracy: 0.8242 - val_loss: 0.4701
# Epoch 44/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9550 - loss: 0.1092 - val_accuracy: 0.8288 - val_loss: 0.5572
# Epoch 45/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9616 - loss: 0.1117 - val_accuracy: 0.7712 - val_loss: 0.8695
# Epoch 46/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 41s 154ms/step - accuracy: 0.9574 - loss: 0.1097 - val_accuracy: 0.4545 - val_loss: 5.5851
# Epoch 47/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9026 - loss: 0.2359 - val_accuracy: 0.8106 - val_loss: 0.4881
# Epoch 48/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 155ms/step - accuracy: 0.9379 - loss: 0.1481 - val_accuracy: 0.8364 - val_loss: 0.4517
# Epoch 49/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9548 - loss: 0.1182 - val_accuracy: 0.8500 - val_loss: 0.4491
# Epoch 50/50
# 165/165 ━━━━━━━━━━━━━━━━━━━━ 26s 154ms/step - accuracy: 0.9663 - loss: 0.0887 - val_accuracy: 0.8348 - val_loss: 0.4909

# %% [markdown]
# **plots for accuracy and Loss with epochs**

# %%
tr_acc = history1.history['accuracy']
tr_loss = history1.history['loss']
val_acc = history1.history['val_accuracy']
val_loss = history1.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# **Evaluvate Model**

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9958 - loss: 0.0295
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.7683 - loss: 0.7218
# Train Loss:  0.048200104385614395
# Train Accuracy:  0.987500011920929
# --------------------
# Test Loss:  0.530651330947876
# Test Accuracy:  0.824999988079071

# %% [markdown]
# **predict**

# %%
result = model.predict(test_gen)

y_pred = np.argmax(result, axis = 1)

y_true = test_gen.labels

# Evaluvate
loss,acc = model.evaluate(test_gen)

print('The accuracy of the model for testing data is:',acc*100)
print('The Loss of the model for testing data is:',loss)
# Out:
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8233 - loss: 0.5275
# The accuracy of the model for testing data is: 83.48484635353088
# The Loss of the model for testing data is: 0.4908739924430847

# %% [markdown]
# **classification_report**

# %%
print(classification_report(y_true, y_pred,target_names=classes))
# Out:
#               precision    recall  f1-score   support
#
#       benign       0.85      0.84      0.85       360
#    malignant       0.82      0.82      0.82       300
#
#     accuracy                           0.83       660
#    macro avg       0.83      0.83      0.83       660
# weighted avg       0.84      0.83      0.83       660
